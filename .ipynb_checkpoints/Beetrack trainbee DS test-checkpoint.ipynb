# %%
# !pip install boto3
# Out:
# ...
# You are using pip version 18.1, however version 21.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !pip install sqlalchemy
# Out:
# ...
# You are using pip version 18.1, however version 21.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import boto3
import sqlalchemy
import pandas as pd

# %%
# credentials
# AWS
AWS_ACCESS_KEY_ID = "AKIAYNKI4OWQL3LE645A"
AWS_SECRET_ACCESS_KEY = "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"
AWS_DEFAULT_REGION = "us-west-2"

# %%
session = boto3.Session(
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
    region_name = AWS_DEFAULT_REGION
)
s3 = session.resource('s3')

# %%
my_bucket = s3.Bucket('trainbee-billing')

for my_bucket_object in my_bucket.objects.all():
    print(my_bucket_object.key)
# Out:
# CL/
# CL/CL_billing_2021-12.json
# MX/
# MX/MX_billing_2021-12.json

# %%
for s3_object in my_bucket.objects.all():
   
    if "CL_" in s3_object.key:
        my_bucket.download_file(s3_object.key, 'CL_billing.json')
    elif "MX_" in s3_object.key:
        my_bucket.download_file(s3_object.key, 'MX_billing.json')

# %%
import json

# %%
with open('CL_billing.json', encoding='utf-8') as CL:
    cl_billing = json.load(CL)
with open('MX_billing.json', encoding='utf-8') as MX:
    mx_billing = json.load(MX)

# %%
cl_billing
# Out:
# {'date': '2021-12-01',
#  'data': [{'id': 1,
#    'line': [{'description': 'Uso de software logistica',
#      'currency': 'clp',
#      'amount': 12000},
#     {'description': 'Servicio de mensajería',
#      'currency': 'clp',
#      'amount': 20000}]},
#   {'id': 2,
#    'line': [{'description': 'Uso de software logistica',
#      'currency': 'clp',
#      'amount': 19500},
#     {'description': 'Servicío de almacenamiento',
#      'currency': 'clp',
#      'amount': 28500},
#     {'description': 'Otros', 'currency': 'clp', 'amount': 7500},
#     {'description': 'Servicio de mensajería',
#      'currency': 'clp',
#      'amount': 7000}]},
#   {'id': 3,
#    'line': [{'description': 'Servicio de mensajería',
#      'currency': 'clp',
#      'amount': 19500},
#     {'description': 'Servicío de almacenamiento',
#      'currency': 'clp',
#      'amount': 22000},
#     {'description': 'Otros', 'currency': 'clp', 'amount': 20000}]},
#   {'id': 4,
# ...

# %%
with open('CL_billing.json', encoding='utf-8') as CL:
    df_cl = pd.read_json(CL)
with open('MX_billing.json', encoding='utf-8') as MX:
    df_mx = pd.read_json(MX)

# %%
df_cl
# Out:
#          date                                               data
# 0  2021-12-01  {'id': 1, 'line': [{'description': 'Uso de sof...
# 1  2021-12-01  {'id': 2, 'line': [{'description': 'Uso de sof...
# 2  2021-12-01  {'id': 3, 'line': [{'description': 'Servicio d...
# 3  2021-12-01  {'id': 4, 'line': [{'description': 'Servicio d...
# 4  2021-12-01  {'id': 5, 'line': [{'description': 'Servicio d...
# 5  2021-12-01  {'id': 6, 'line': [{'description': 'Servicío d...
# 6  2021-12-01  {'id': 7, 'line': [{'description': 'Otros', 'c...
# 7  2021-12-01  {'id': 8, 'line': [{'description': 'Uso de sof...
# 8  2021-12-01  {'id': 9, 'line': [{'description': 'Servicio d...
# 9  2021-12-01  {'id': 10, 'line': [{'description': 'Otros', '...
# 10 2021-12-01  {'id': 11, 'line': [{'description': 'Servicío ...
# 11 2021-12-01  {'id': 12, 'line': [{'description': 'Servicío ...
# 12 2021-12-01  {'id': 13, 'line': [{'description': 'Uso de so...
# ...

# %%
mod_df_cl = pd.concat([df_cl.drop(['data'], axis=1), df_cl['data'].apply(pd.Series)], axis=1)

# %%
mod_df_cl
# Out:
#          date  id                                               line
# 0  2021-12-01   1  [{'description': 'Uso de software logistica', ...
# 1  2021-12-01   2  [{'description': 'Uso de software logistica', ...
# 2  2021-12-01   3  [{'description': 'Servicio de mensajería', 'cu...
# 3  2021-12-01   4  [{'description': 'Servicio de mensajería', 'cu...
# 4  2021-12-01   5  [{'description': 'Servicio de mensajería', 'cu...
# 5  2021-12-01   6  [{'description': 'Servicío de almacenamiento',...
# 6  2021-12-01   7  [{'description': 'Otros', 'currency': 'clp', '...
# 7  2021-12-01   8  [{'description': 'Uso de software logistica', ...
# 8  2021-12-01   9  [{'description': 'Servicio de mensajería', 'cu...
# 9  2021-12-01  10  [{'description': 'Otros', 'currency': 'clp', '...
# 10 2021-12-01  11  [{'description': 'Servicío de almacenamiento',...
# 11 2021-12-01  12  [{'description': 'Servicío de almacenamiento',...
# 12 2021-12-01  13  [{'description': 'Uso de software logistica', ...
# ...

# %%
mod_df_cl.loc[0, 'line']
# Out:
# [{'description': 'Uso de software logistica',
#   'currency': 'clp',
#   'amount': 12000},
#  {'description': 'Servicio de mensajería', 'currency': 'clp', 'amount': 20000}]

# %%
mod_df_cl = mod_df_cl.explode('line')

# %%
mod_df_cl
# Out:
#          date  id                                               line
# 0  2021-12-01   1  {'description': 'Uso de software logistica', '...
# 0  2021-12-01   1  {'description': 'Servicio de mensajería', 'cur...
# 1  2021-12-01   2  {'description': 'Uso de software logistica', '...
# 1  2021-12-01   2  {'description': 'Servicío de almacenamiento', ...
# 1  2021-12-01   2  {'description': 'Otros', 'currency': 'clp', 'a...
# 1  2021-12-01   2  {'description': 'Servicio de mensajería', 'cur...
# 2  2021-12-01   3  {'description': 'Servicio de mensajería', 'cur...
# 2  2021-12-01   3  {'description': 'Servicío de almacenamiento', ...
# 2  2021-12-01   3  {'description': 'Otros', 'currency': 'clp', 'a...
# 3  2021-12-01   4  {'description': 'Servicio de mensajería', 'cur...
# 4  2021-12-01   5  {'description': 'Servicio de mensajería', 'cur...
# 4  2021-12-01   5  {'description': 'Otros', 'currency': 'clp', 'a...
# 4  2021-12-01   5  {'description': 'Uso de software logistica', '...
# ...

# %%
mod_df_cl = pd.concat([mod_df_cl.drop(['line'], axis=1), mod_df_cl['line'].apply(pd.Series)], axis=1)

# %%
mod_df_cl
# Out:
#          date  id                 description currency  amount
# 0  2021-12-01   1   Uso de software logistica      clp   12000
# 0  2021-12-01   1      Servicio de mensajería      clp   20000
# 1  2021-12-01   2   Uso de software logistica      clp   19500
# 1  2021-12-01   2  Servicío de almacenamiento      clp   28500
# 1  2021-12-01   2                       Otros      clp    7500
# 1  2021-12-01   2      Servicio de mensajería      clp    7000
# 2  2021-12-01   3      Servicio de mensajería      clp   19500
# 2  2021-12-01   3  Servicío de almacenamiento      clp   22000
# 2  2021-12-01   3                       Otros      clp   20000
# 3  2021-12-01   4      Servicio de mensajería      clp   10500
# 4  2021-12-01   5      Servicio de mensajería      clp    7500
# 4  2021-12-01   5                       Otros      clp   21500
# 4  2021-12-01   5   Uso de software logistica      clp   16000
# 5  2021-12-01   6  Servicío de almacenamiento      clp    8500
# ...

# %%
#For MX
mod_df_mx = pd.concat([df_mx.drop(['data'], axis=1), df_mx['data'].apply(pd.Series)], axis=1)
mod_df_mx = mod_df_mx.explode('line')
mod_df_mx = pd.concat([mod_df_mx.drop(['line'], axis=1), mod_df_mx['line'].apply(pd.Series)], axis=1)

# %%
df_mx = mod_df_mx
df_cl = mod_df_cl

# %%
# !pip install pymysql

# %%
from sqlalchemy import create_engine

# %%
# BD
Host = 'trainbee-billing.c6zttpwnotj0.us-west-2.rds.amazonaws.com'
Port = '3306'
Database = 'datawarehouse'
User = 'dataengineer'
Pass = 'goXC7KH!WfPc'

# %%
print(User)
print(Pass)
print(Host)
print(Port)
print(Database)
# Out:
# dataengineer
# goXC7KH!WfPc
# trainbee-billing.c6zttpwnotj0.us-west-2.rds.amazonaws.com
# 3306
# datawarehouse

# %%
import urllib.parse
a = urllib.parse.quote_plus(Pass)
a
# Out:
# 'goXC7KH%21WfPc'

# %%
mysql_url = f'mysql+pymysql://{User}:{Pass}@{Host}:{Port}/{Database}'
engine = create_engine(mysql_url)
engine.connect()
#print(engine.table_names())

# %%
companies = pd.read_sql_table(table_name='companies', con=engine)
currencies_to_usd = pd.read_sql_table(table_name='currencies_to_usd', con=engine)

# %%
companies
# Out:
#     id           name                       website updated_at
# 0    1            Yac              https://yac.chat 2020-02-15
# 1    2    SmartKarrot  https://www.smartkarrot.com/ 2020-11-27
# 2    3    SIMBA Chain     http://www.simbachain.com 2020-06-09
# 3    4        Seatrec           http://seatrec.com/ 2020-10-13
# 4    5      Prodsight      https://www.prodsight.ai 2021-02-26
# 5    6        Prisync           https://prisync.com 2020-07-25
# 6    7      Podsights        https://podsights.com/ 2020-08-31
# 7    8       Internxt         https://internxt.com/ 2020-11-04
# 8    9        HeyTeam        http://www.heyteam.com 2020-02-24
# 9   10       Harvestr           http://harvestr.io/ 2020-05-27
# 10  11   Fundraise Up       https://fundraiseup.com 2020-07-29
# 11  12          Float      https://www.floatapp.com 2020-04-13
# 12  13       Dockflow          https://dockflow.com 2020-03-04
# 13  14         Docket          https://dockethq.com 2021-01-28
# ...

# %%
currencies_to_usd
# Out:
#   currency       usd
# 0      CLP  0.001226
# 1      MXN  0.049229
# 2      USD  1.000000

# %%
df_cl['country'] = 'Chile'
df_mx['country'] = 'Mexico'

# %%
df_cl['amount_usd'] = df_cl['amount'].apply(lambda x: x*currencies_to_usd.loc[currencies_to_usd['currency'] == 'CLP', 'usd'].values[0])

# %%
df_cl
# Out:
#          date  id                 description currency  amount country  \
# 0  2021-12-01   1   Uso de software logistica      clp   12000   Chile
# 0  2021-12-01   1      Servicio de mensajería      clp   20000   Chile
# 1  2021-12-01   2   Uso de software logistica      clp   19500   Chile
# 1  2021-12-01   2  Servicío de almacenamiento      clp   28500   Chile
# 1  2021-12-01   2                       Otros      clp    7500   Chile
# 1  2021-12-01   2      Servicio de mensajería      clp    7000   Chile
# 2  2021-12-01   3      Servicio de mensajería      clp   19500   Chile
# 2  2021-12-01   3  Servicío de almacenamiento      clp   22000   Chile
# 2  2021-12-01   3                       Otros      clp   20000   Chile
# 3  2021-12-01   4      Servicio de mensajería      clp   10500   Chile
# 4  2021-12-01   5      Servicio de mensajería      clp    7500   Chile
# 4  2021-12-01   5                       Otros      clp   21500   Chile
# ...

# %%
def cond_func(a,b):
    if a == 'mxn':
        return b*0.049229
    else:
        return round(b)

# %%
df_mx['amount_usd'] = df_mx.apply(lambda x: cond_func(x['currency'], x['amount']), axis=1)

# %%
df_mx
# Out:
#          date  id                 description currency  amount country  \
# 0  2021-12-01   1                       Otros      mxn    8000  Mexico
# 0  2021-12-01   1  Servicío de almacenamiento      mxn     500  Mexico
# 0  2021-12-01   1   Uso de software logistica      usd    3500  Mexico
# 0  2021-12-01   1      Servicio de mensajería      mxn    6500  Mexico
# 1  2021-12-01   2      Servicio de mensajería      mxn    2000  Mexico
# 1  2021-12-01   2   Uso de software logistica      mxn     500  Mexico
# 1  2021-12-01   2                       Otros      mxn    1500  Mexico
# 1  2021-12-01   2  Servicío de almacenamiento      mxn    8500  Mexico
# 2  2021-12-01   3                       Otros      usd    1000  Mexico
# 2  2021-12-01   3   Uso de software logistica      usd    7500  Mexico
# 3  2021-12-01   4   Uso de software logistica      mxn    8000  Mexico
# 4  2021-12-01   5      Servicio de mensajería      mxn     500  Mexico
# ...

# %%
df_cl
# Out:
#          date  id                 description currency  amount country  \
# 0  2021-12-01   1   Uso de software logistica      clp   12000   Chile
# 0  2021-12-01   1      Servicio de mensajería      clp   20000   Chile
# 1  2021-12-01   2   Uso de software logistica      clp   19500   Chile
# 1  2021-12-01   2  Servicío de almacenamiento      clp   28500   Chile
# 1  2021-12-01   2                       Otros      clp    7500   Chile
# 1  2021-12-01   2      Servicio de mensajería      clp    7000   Chile
# 2  2021-12-01   3      Servicio de mensajería      clp   19500   Chile
# 2  2021-12-01   3  Servicío de almacenamiento      clp   22000   Chile
# 2  2021-12-01   3                       Otros      clp   20000   Chile
# 3  2021-12-01   4      Servicio de mensajería      clp   10500   Chile
# 4  2021-12-01   5      Servicio de mensajería      clp    7500   Chile
# 4  2021-12-01   5                       Otros      clp   21500   Chile
# ...

# %%
companies.loc[companies['id']==5, ['name', 'website']]
# Out:
#         name                   website
# 4  Prodsight  https://www.prodsight.ai

# %%
companies
# Out:
#     id           name                       website updated_at
# 0    1            Yac              https://yac.chat 2020-02-15
# 1    2    SmartKarrot  https://www.smartkarrot.com/ 2020-11-27
# 2    3    SIMBA Chain     http://www.simbachain.com 2020-06-09
# 3    4        Seatrec           http://seatrec.com/ 2020-10-13
# 4    5      Prodsight      https://www.prodsight.ai 2021-02-26
# 5    6        Prisync           https://prisync.com 2020-07-25
# 6    7      Podsights        https://podsights.com/ 2020-08-31
# 7    8       Internxt         https://internxt.com/ 2020-11-04
# 8    9        HeyTeam        http://www.heyteam.com 2020-02-24
# 9   10       Harvestr           http://harvestr.io/ 2020-05-27
# 10  11   Fundraise Up       https://fundraiseup.com 2020-07-29
# 11  12          Float      https://www.floatapp.com 2020-04-13
# 12  13       Dockflow          https://dockflow.com 2020-03-04
# 13  14         Docket          https://dockethq.com 2021-01-28
# ...

# %%
new_mx = pd.merge(df_mx, companies, on='id')
new_mx = new_mx.drop(columns='updated_at')

# %%
new_mx.head()
# Out:
#         date  id                 description currency  amount country  \
# 0 2021-12-01   1                       Otros      mxn    8000  Mexico
# 1 2021-12-01   1                       Otros      mxn    8000  Mexico
# 2 2021-12-01   1  Servicío de almacenamiento      mxn     500  Mexico
# 3 2021-12-01   1  Servicío de almacenamiento      mxn     500  Mexico
# 4 2021-12-01   1   Uso de software logistica      usd    3500  Mexico
#
#    amount_usd name           website
# 0    393.8320  Yac  https://yac.chat
# 1    393.8320  Yac  https://yac.chat
# 2     24.6145  Yac  https://yac.chat
# 3     24.6145  Yac  https://yac.chat
# 4   3500.0000  Yac  https://yac.chat

# %%
new_mx = new_mx.drop_duplicates()

# %%
new_mx.loc[new_mx['name'] == 'SIMBA Chain', :]
# Out:
#          date  id                description currency  amount country  \
# 12 2021-12-01   3                      Otros      usd    1000  Mexico
# 14 2021-12-01   3  Uso de software logistica      usd    7500  Mexico
#
#     amount_usd         name                    website
# 12      1000.0  SIMBA Chain  http://www.simbachain.com
# 14      7500.0  SIMBA Chain  http://www.simbachain.com

# %%
new_cl = pd.merge(df_cl, companies, on='id')
new_cl = new_cl.drop(columns='updated_at')
new_cl = new_cl.drop_duplicates()

# %%
new_cl
# Out:
#          date  id                 description currency  amount country  \
# 0  2021-12-01   1   Uso de software logistica      clp   12000   Chile
# 2  2021-12-01   1      Servicio de mensajería      clp   20000   Chile
# 4  2021-12-01   2   Uso de software logistica      clp   19500   Chile
# 5  2021-12-01   2  Servicío de almacenamiento      clp   28500   Chile
# 6  2021-12-01   2                       Otros      clp    7500   Chile
# 7  2021-12-01   2      Servicio de mensajería      clp    7000   Chile
# 8  2021-12-01   3      Servicio de mensajería      clp   19500   Chile
# 10 2021-12-01   3  Servicío de almacenamiento      clp   22000   Chile
# 12 2021-12-01   3                       Otros      clp   20000   Chile
# 14 2021-12-01   4      Servicio de mensajería      clp   10500   Chile
# 16 2021-12-01   5      Servicio de mensajería      clp    7500   Chile
# 17 2021-12-01   5                       Otros      clp   21500   Chile
# ...

# %%
new_cl.rename(columns={'date': 'billing_date', 'description': 'product'}, inplace=True)
new_mx.rename(columns={'date': 'billing_date', 'description': 'product'}, inplace=True)

# %%
new_full = new_cl.append(new_mx, ignore_index = True)

# %%
new_full = new_full.reset_index(drop=True)

# %%
new_full
# Out:
#     billing_date  id                     product currency  amount country  \
# 0     2021-12-01   1   Uso de software logistica      clp   12000   Chile
# 1     2021-12-01   1      Servicio de mensajería      clp   20000   Chile
# 2     2021-12-01   2   Uso de software logistica      clp   19500   Chile
# 3     2021-12-01   2  Servicío de almacenamiento      clp   28500   Chile
# 4     2021-12-01   2                       Otros      clp    7500   Chile
# ..           ...  ..                         ...      ...     ...     ...
# 104   2021-12-01  19   Uso de software logistica      mxn    6000  Mexico
# 105   2021-12-01  19      Servicio de mensajería      mxn    7000  Mexico
# 106   2021-12-01  20   Uso de software logistica      mxn    3500  Mexico
# 107   2021-12-01  20  Servicío de almacenamiento      usd    6000  Mexico
# 108   2021-12-01  20                       Otros      mxn    1500  Mexico
#
#      amount_usd         name                       website
# ...

# %%
total = new_full['amount_usd'].sum()

# %%
total
# Out:
# 161281.4285

# %%
cols = list(new_full.columns.values)

# %%
cols
# Out:
# ['billing_date',
#  'id',
#  'product',
#  'currency',
#  'amount',
#  'country',
#  'amount_usd',
#  'name',
#  'website']

# %%
df = new_full[['id', 'name', 'website', 'country', 'product', 'currency', 'amount', 'amount_usd', 'billing_date']]

# %%
df
# Out:
#      id         name                       website country  \
# 0     1          Yac              https://yac.chat   Chile
# 1     1          Yac              https://yac.chat   Chile
# 2     2  SmartKarrot  https://www.smartkarrot.com/   Chile
# 3     2  SmartKarrot  https://www.smartkarrot.com/   Chile
# 4     2  SmartKarrot  https://www.smartkarrot.com/   Chile
# ..   ..          ...                           ...     ...
# 104  19        Banxa            https://banxa.com/  Mexico
# 105  19        Banxa            https://banxa.com/  Mexico
# 106  20    api.video             https://api.video  Mexico
# 107  20    api.video             https://api.video  Mexico
# 108  20    api.video             https://api.video  Mexico
#
#                         product currency  amount  amount_usd billing_date
# 0     Uso de software logistica      clp   12000     14.7120   2021-12-01
# 1        Servicio de mensajería      clp   20000     24.5200   2021-12-01
# ...

# %%
df.to_sql('billing', engine, if_exists='replace', index = False)

# %%
print(engine.table_names())
# Out:
# c:\users\alanp\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.
# ['billing', 'companies', 'currencies_to_usd']

# %%
testing = pd.read_sql_table(table_name='billing', con=engine)

# %%
testing
# Out:
#      id         name                       website country  \
# 0     1          Yac              https://yac.chat   Chile
# 1     1          Yac              https://yac.chat   Chile
# 2     2  SmartKarrot  https://www.smartkarrot.com/   Chile
# 3     2  SmartKarrot  https://www.smartkarrot.com/   Chile
# 4     2  SmartKarrot  https://www.smartkarrot.com/   Chile
# ..   ..          ...                           ...     ...
# 104  19        Banxa            https://banxa.com/  Mexico
# 105  19        Banxa            https://banxa.com/  Mexico
# 106  20    api.video             https://api.video  Mexico
# 107  20    api.video             https://api.video  Mexico
# 108  20    api.video             https://api.video  Mexico
#
#                         product currency  amount  amount_usd billing_date
# 0     Uso de software logistica      clp   12000     14.7120   2021-12-01
# 1        Servicio de mensajería      clp   20000     24.5200   2021-12-01
# ...

# %%
print(f'El total facturado en Diciembre fue de ${total} USD')
# Out:
# El total facturado en Diciembre fue de $161281.4285 USD
